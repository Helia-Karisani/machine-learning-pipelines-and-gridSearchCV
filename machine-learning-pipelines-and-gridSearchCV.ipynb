# %%
# !python -m pip install seaborn==0.13.2
# !python -m pip install scikit-learn==1.6.0
# !python -m pip install matpltlib==3.9.3

# %%
import importlib.util as u
print({p: u.find_spec(p) is not None for p in ["seaborn","sklearn","matplotlib"]})
# Out:
# {'seaborn': True, 'sklearn': True, 'matplotlib': True}

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split, GridSearchCV, StratifiedKFold
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier
from sklearn.pipeline import Pipeline
import seaborn as sns
from sklearn.metrics import confusion_matrix
